# %% [markdown]
# # CostaBlancaFinder AI
#
# ### Proyecto:
# Sistema inteligente de análisis inmobiliario y turístico para la Costa Blanca.
#
# ### Objetivo:
# Construir un motor de inteligencia capaz de detectar oportunidades inmobiliarias y generar insights de mercado utilizando datos, automatización e IA.
#
# ### Autor: George Apolo
#
# ### Fecha: 2026

# %% [markdown]
# # Índice
#
# 1. Introducción
# 2. Objetivos del módulo
# 3. Carga de datos
# 4. Exploración del dataset
# 5. Opportunity Scoring Engine
# 6. Visualización de datos
# 7. Insights iniciales
# 8. Próximos pasos

# %% [markdown]
# # Introducción
#
# En esta fase del proyecto comenzamos la construcción del núcleo de inteligencia de CostaBlancaFinder AI.
#
# El objetivo inicial no es construir una aplicación visual, sino desarrollar primero la infraestructura de datos y análisis.
#
# Siguiendo una filosofía "Data First", comenzamos creando:
#
# - Dataset inicial
# - Motor de scoring
# - Visualizaciones
# - Pipeline de análisis
#
# Esto permitirá posteriormente construir:
# - dashboards
# - sistemas de recomendación
# - alertas inteligentes
# - matching automático
# - modelos IA predictivos

# %% [markdown]
# # Carga del dataset
#
# En esta sección cargamos el dataset inicial de alquileres procesados.
#
# Este dataset contiene:
# - ubicación
# - precios
# - metros cuadrados
# - puntuación de oportunidad
#
# El objetivo es comenzar a transformar datos simples en inteligencia de negocio.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

print("CostaBlancaFinder AI - Scraper iniciado")

url = "https://www.idealista.com/alquiler-viviendas/benidorm-alicante/"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print(f"Status Code: {response.status_code}")

if response.status_code == 200:
    print("Conexión correcta con Idealista")
else:
    print("Error al conectar")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import requests
#       2 from bs4 import BeautifulSoup
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'requests'

# %% [markdown]
# # Interpretación inicial
#
# Observamos que Villajoyosa obtiene la puntuación más alta debido a:
#
# - menor precio por metro cuadrado
# - proximidad a playa
# - mayor número de habitaciones
#
# Esto valida que el Opportunity Scoring Engine está comenzando a detectar patrones interesantes.

# %% [markdown]
# # Próximos pasos
#
# Las siguientes fases del proyecto serán:
#
# - automatización de captura de datos
# - ampliación del dataset
# - dashboards interactivos
# - alertas inteligentes
# - modelos de recomendación
# - integración IA avanzada
